# %%
from PIL import Image
from imgtools import *
from IPython.display import display

# %%
dir = 'C:/Pictures/1.png'

# %%
img = load_image(dir)

# %%
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=380x449>

# %%
print(img.size)
# Out:
# (380, 449)

# %%
new_size = (1000,1000)
new_image = img.resize(new_size)
display(new_image)
new_image.save('C:/Pictures/6.png')
# Out:
# <PIL.Image.Image image mode=RGBA size=1000x1000>

# %%
thumbnail_size = (50,50)
img.thumbnail(thumbnail_size)
display(img)
img.save('C:/Pictures/7.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=42x50>
