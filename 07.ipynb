# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from PIL import Image

# %%
# Đường dẫn ảnh
my_path = 'C:/Pictures/8.jpg'
# Đọc ảnh và hiển thị
im = Image.open(my_path)
# display(im)
plt.imshow(im)

# %%
x = [1, 2, 3, 4, 5]
y = [27, 14, 22, 9, 1]
plt.plot(x, y)
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [27, 14, 22, 9, 1]
plt.plot(x, y, color='red')
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [27, 14, 22, 9, 1]
plt.plot(x, y, color='red') # Màu sắc
plt.title('Ví dụ về biểu đồ') # Title
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [27, 14, 22, 9, 1]
plt.plot(x, y, color='red') # Màu sắc
plt.title('Ví dụ về biểu đồ') # Title
plt.axis('off')
plt.show()

# %%
im = Image.open(my_path)
x = [200, 300, 500, 900]
y = [200, 300, 200, 300]

plt.imshow(im) # Hiển thị hình ảnh
plt.plot(x,y, 'bo--') 
plt.show()
