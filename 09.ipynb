# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
my_path = 'C:/Pictures/8.jpg'

im = Image.open(my_path)
plt.imshow(im)

# %%
im_gray = im.convert('L')
plt.imshow(im_gray, cmap='gray')

# %%
im_array = np.array(im_gray)
print(im_array)
# Out:
# [[98 98 98 ... 92 91 91]
#  [98 98 98 ... 95 95 94]
#  [98 98 98 ... 99 98 98]
#  ...
#  [93 59 55 ... 33 31 37]
#  [83 73 45 ... 36 35 41]
#  [71 94 35 ... 42 40 46]]

# %%
plt.figure()
plt.hist(im_array.flatten(), bins=200)
plt.title('Biểu đồ Histogram của ảnh')
plt.xlabel('Giá trị của pixel')
plt.ylabel('Số lượng')
plt.show()

# %%
plt.figure()
plt.gray()
plt.contour(im_gray, origin="image")
plt.show()

# %%
my_path = 'C:/Pictures/9.jpg'
im = Image.open(my_path).convert("L")
plt.imshow(im)

plt.figure()
plt.gray()
plt.contour(im, origin="image")
plt.axis('equal')
plt.show()
