# %%
from PIL import Image
from imgtools import *
from IPython.display import display

# %%
dir = 'C:/Pictures'

# %%
imgs =  get_image_list(dir)

# %%
display(imgs)
# Out:
# [<PIL.PngImagePlugin.PngImageFile image mode=RGBA size=380x449>,
#  <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=171x525>,
#  <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1303x356>,
#  <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=660x638>,
#  <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=412x267>]

# %%
for img in imgs:
    display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=380x449>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=171x525>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1303x356>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=660x638>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=412x267>
